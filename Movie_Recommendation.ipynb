# %% [markdown]
# <a href="https://colab.research.google.com/github/nakibahsan299-debug/Movie-Recommendation-System/blob/Nakib/Movie_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
